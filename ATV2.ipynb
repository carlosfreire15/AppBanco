# %% [markdown]
# <a href="https://colab.research.google.com/github/carlosfreire15/AppBanco/blob/master/ATV2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
CARLOS EDUARDO MARTINS FREIRE
195767

# %%
import pandas as pd ##Adicionando a a biblioteca do pandas

compradores = pd.read_csv("Customers.csv")

# %%
compradores.head(8)
# Out:
#    CustomerID  Gender  Age  Annual Income ($)  Spending Score (1-100)  \
# 0           1    Male   19              15000                      39
# 1           2    Male   21              35000                      81
# 2           3  Female   20              86000                       6
# 3           4  Female   23              59000                      77
# 4           5  Female   31              38000                      40
# 5           6  Female   22              58000                      76
# 6           7  Female   35              31000                       6
# 7           8  Female   23              84000                      94
#
#       Profession  Work Experience  Family Size
# 0     Healthcare                1            4
# 1       Engineer                3            3
# 2       Engineer                1            1
# 3         Lawyer                0            2
# 4  Entertainment                2            6
# 5         Artist                0            2
# ...

# %%
compradores.describe(include="all")
# Out:
#          CustomerID  Gender          Age  Annual Income ($)  \
# count   2000.000000    2000  2000.000000        2000.000000
# unique          NaN       2          NaN                NaN
# top             NaN  Female          NaN                NaN
# freq            NaN    1186          NaN                NaN
# mean    1000.500000     NaN    48.960000      110731.821500
# std      577.494589     NaN    28.429747       45739.536688
# min        1.000000     NaN     0.000000           0.000000
# 25%      500.750000     NaN    25.000000       74572.000000
# 50%     1000.500000     NaN    48.000000      110045.000000
# 75%     1500.250000     NaN    73.000000      149092.750000
# max     2000.000000     NaN    99.000000      189974.000000
#
#         Spending Score (1-100) Profession  Work Experience  Family Size
# count              2000.000000       1965      2000.000000  2000.000000
# unique                     NaN          9              NaN          NaN
# ...

# %%
compradores["Gender"].describe()
##usando o comando DESCRIBE PARA UMA COLUNA EM ESPECÍFICO
# Out:
# count       2000
# unique         2
# top       Female
# freq        1186
# Name: Gender, dtype: object

# %%
compradores["Profession"].value_counts()
# Out:
# Artist           612
# Healthcare       339
# Entertainment    234
# Engineer         179
# Doctor           161
# Executive        153
# Lawyer           142
# Marketing         85
# Homemaker         60
# Name: Profession, dtype: int64
